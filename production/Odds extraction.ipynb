# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import datetime
import warnings
import requests
import json
import sys
import os

pd.set_option('display.max_columns', 500)
warnings.filterwarnings('ignore')

# %%
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.proxy import Proxy, ProxyType
from selenium import webdriver

proxy_address = "127.0.0.1:9150"

# Setting up my Tor initialization
if sys.platform=="win32":
    tor = r'C:\Users\cliffchew84\Desktop\Tor Browser\Browser\firefox'
else:
    tor = r'/Applications/TorBrowser.app/Contents/MacOS/firefox'

# %%
if sys.platform=="win32":
    browser = webdriver.Chrome('C:\Users\cliffchew84\Desktop\chromedriver_win32\chromedriver.exe')
else:
    firefox_binary = FirefoxBinary(tor)
    browser = webdriver.Firefox(firefox_binary=firefox_binary)

# %%
test_page = "https://www.pinnacle.com/en/odds/match/basketball/usa/nba?sport=True"

# %%
browser.get(test_page)
soup = bs(browser.page_source)

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en" class="lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html lang="en" class="lt-ie9 lt-ie8" xmlns:ng="http://angularjs.org"> <![endif]--><!--[if IE 8]>         <html lang="en" class="lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html lang="en" xmlns="http://www.w3.org/1999/xhtml"><!--<![endif]--><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\:form{display:block;}.ng-animate-block-transitions{transition:0s all!important;-webkit-transition:0s all!important;}.ng-hide-add-active,.ng-hide-remove{display:block!important;}</style>
# <!--[if lte IE 7]>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1" />
#     <![endif]-->
# <meta charset="utf-8"/>
# <title>USA NBA Odds, Basketball USA NBA Betting</title>
# <link href="https://www.pinnacle.com/en/odds/match/basketball/usa/nba" rel="canonical"/><meta content="Basketball NBA Betting. Bet with Best USA NBA Odds at Pinnacle. Always the Best Basketball Odds Online!" name="description"/><meta content="summary" name="twitter:card"/><meta content="NBA Odds, Basketball NBA Betting" name="twitter:title"/><meta content="Basketball NBA Betting. Bet with Best USA NBA Odds at Pinnacle. Always the Best Basketball Odds Online!" name="twitter:description"/><meta content="https://www.pinnacle.com/en/odds/match/Basketball/USA/NBA" name="twitter:url"/><meta content="https://www.pinnacle.com/Cms_Data/Contents/Guest/Media/Twitter/basketball.jpg" name="twitter:image"/><meta content="@PinnacleSports" name="twitter:site"/>
# <link href="https://www.pinnacle.com/sv/odds/match/basketball/usa/nba" hreflang="sv" rel="alternate"/>
# <link href="https://www.pinnacle.com/es/odds/match/basketball/usa/nba" hreflang="es" rel="alternate"/>
# <link href="https://www.pinnacle.com/pt/odds/match/basketball/usa/nba" hreflang="pt" rel="alternate"/>
# <link href="https://www.pinnacle.com/no/odds/match/basketball/usa/nba" hreflang="no" rel="alternate"/>
# <link href="https://www.pinnacle.com/ko/odds/match/basketball/usa/nba" hreflang="ko" rel="alternate"/>
# <link href="https://www.pinnacle.com/ja/odds/match/basketball/usa/nba" hreflang="ja" rel="alternate"/>
# <link href="https://www.pinnacle.com/it/odds/match/basketball/usa/nba" hreflang="it" rel="alternate"/>
# <link href="https://www.pinnacle.com/he/odds/match/basketball/usa/nba" hreflang="he" rel="alternate"/>
# <link href="https://www.pinnacle.com/fr/odds/match/basketball/usa/nba" hreflang="fr" rel="alternate"/>
# <link href="https://www.pinnacle.com/fi/odds/match/basketball/usa/nba" hreflang="fi" rel="alternate"/>
# <link href="https://www.pinnacle.com/cs/odds/match/basketball/usa/nba" hreflang="cs" rel="alternate"/>
# <link href="https://www.pinnacle.com/zh-tw/odds/match/basketball/usa/nba" hreflang="zh-tw" rel="alternate"/>
# <link href="https://www.pinnacle.com/zh-cn/odds/match/basketball/usa/nba" hreflang="zh-cn" rel="alternate"/>
# <link href="https://www.pinnacle.com/pl/odds/match/basketball/usa/nba" hreflang="pl" rel="alternate"/>
# <link href="https://www.pinnacle.com/de/odds/match/basketball/usa/nba" hreflang="de" rel="alternate"/>
# <link href="https://www.pinnacle.com/ru/odds/match/basketball/usa/nba" hreflang="ru" rel="alternate"/>
# <link href="https://www.pinnacle.com/en/odds/match/basketball/usa/nba" hreflang="en" rel="alternate"/>
# <link href="/Guest/Kooboo-Resource/theme/1_0_0_20171103192757/true/Default" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 7]>
#     <style type="text/css">
#     [ng\:cloak], [ng-cloak], .ng-cloak {
#       display: none !important;
#     }
#     </style>
#     <![endif]-->
# <!--[if lt IE 9]>
#     <script type="text/javascript" src="/Guest/Kooboo-Resource/scripts/1_0_0_20171103192757/True/html5" ></script>
#
#     <![endif]-->
# <!--[if lte IE 9]>
#     <script type="text/javascript" src="/Guest/Kooboo-Resource/scripts/1_0_0_20171103192757/True/es5" ></script>
#
#     <![endif]-->
# <!--[if lte IE 7]>
# 	<script type="text/javascript" src="/Guest/Kooboo-Resource/scripts/1_0_0_20171103192757/True/json2" ></script>
#
#     <![endif]-->
# <script async="true" src="https://www.intelli-direct.com/e/CognesiaServiceV62.min.js" type="text/javascript"></script><script async="" src="https://cdn.appdynamics.com/adrum-ext.63e9f33be79086444fbb75051659bdae.js"></script><script async="" src="//9jzkiupf.micpn.com/p/js/1.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-PSRW2G"></script><script src="/Guest/Kooboo-Resource/scripts/1_0_0_20171103192757/True/jquery" type="text/javascript"></script>
# <script src="https://www.pinnacle.com/en/cookiepolicy/loader?ref=guestsite&amp;iframeid=cookiepolicy&amp;position=top&amp;ui=desktop" type="text/javascript"></script>
# <script src="//google-analytics.com/cx/api.js"></script>
# <script src="/Cms_Data/Sites/Guest/Scripts/pinnacle/oddsToolTips.js?ver=1" type="text/javascript"></script>
# <script src="/Cms_Data/Sites/Guest/Scripts/pinnacle/freshwidget.js?ver=1" type="text/javascript"></script>
# <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.pinnacle.com/en/odds/match/basketball/usa/nba",
#     "name": "Odds~PreGame",
#     "sameAs": [
#     "https://www.facebook.com/PinnacleSports",
#     "https://twitter.com/pinnaclesports",
#     "https://plus.google.com/+pinnaclesports",
#     "https://www.linkedin.com/company/pinnacle-sports"
#     ]
#     }
# </script>
# <script type="application/ld+json">
#     {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "name": "Odds~PreGame",
#     "alternateName": "Pinnacle Sports",
#     "url": "http://www.pinnacle.com/en/odds/match/basketball/usa/nba",
#     "logo": {
#     "@type": "ImageObject",
#     "url": "http://www.pinnacle.com/Cms_Data/Contents/Guest/Media/logo/pinnacle-logo-150x150.jpg"
#     },
#     "sameAs": [
#     "https://www.facebook.com/PinnacleSports",
#     "https://twitter.com/pinnaclesports",
#     "https://plus.google.com/+pinnaclesports",
#     "https://www.linkedin.com/company/pinnacle-sports"
#     ]
#     }
# </script>
# <link href="/Cms_Data/Sites/Guest/Themes/Default/images/favicon.ico" rel="icon"/>
# <script src="https://s3.amazonaws.com/assets.freshdesk.com/widget/html2canvas.js?ver=2" type="text/javascript"></script><link href="https://s3.amazonaws.com/assets.freshdesk.com/widget/freshwidget.css?ver=2" rel="stylesheet" type="text/css"/><script id="rum" src="https://d2lo2tipcl3aii.cloudfront.net/56A8F463DEF1455683B3042C9180C564/neustar.beacon.js" type="text/javascript"></script><script async="true" src="https://www.intelli-direct.com/e/cpi2/?mi=1987&amp;vi=&amp;si=&amp;cb=iCognesia%2ECbI&amp;pq=&amp;rqr=&amp;sqr=&amp;pwid=c1510410617993602546704710387446&amp;cce=1&amp;sw=1366&amp;sh=768&amp;cd=24&amp;je=2&amp;jsv=185&amp;ul=en-US&amp;ok=&amp;k=&amp;ck=&amp;scv=&amp;vcv=&amp;ppvi=&amp;r=20811087&amp;pr=&amp;tz=-480&amp;dl=https%3A%2F%2Fwww%2Epinnacle%2Ecom%2Fen%2Fodds%2Fmatch%2Fbasketball%2Fusa%2Fnba%3Fsport%3DTrue" type="text/javascript"></script><script async="true" src="https://www.intelli-direct.com/e/cogcv/?aid=1987&amp;callback=iCognesia%2ECbR&amp;vidi=RTS2|a1987|20171111143050|df59171fe1a944fcb2fccac67a17f3ef&amp;sidi=RTS2|a1987|20171111143050|51bb8b68cc8549198d32564610f758b6&amp;pwid=c1510410617993602546704710387446&amp;acc=1&amp;dl=https%3A%2F%2Fwww%2Epinnacle%2Ecom%2Fen%2Fodds%2Fmatch%2Fbasketball%2Fusa%2Fnba%3Fsport%3DTrue&amp;dn=pinnaclesports%2Ecom&amp;ed=2127423600000&amp;pdata=%5B%7B%22Language%22%3A%22undefined%22%2C%20%22Page%20Name%22%3A%22Odds~PreGame%22%2C%20%22Page%20Category%22%3A%22Odds%22%2C%20%22Domain%22%3A%22undefined%22%2C%20%22Site%22%3A%22undefined%22%2C%20%22Referrer%22%3A%22undefined%22%2C%20%22Article%20Author%22%3A%22undefined%22%2C%20%22Article%20Publish%20Date%22%3A%22undefined%22%2C%20%22oddsType%22%3A%22undefined%22%2C%20%22clientID%22%3A%22undefined%22%2C%20%22property%22%3A%22undefined%22%2C%20%22logStatus%22%3A%22undefined%22%2C%20%22view%22%3A%22undefined%22%2C%20%22event%22%3A%22gtm%2Eload%22%7D%5D&amp;rnd=95660540" type="text/javascript"></script></head>
# <body class="ng-app:KoobooApp responsive-body en-code is-guest ng-scope" id="ng-app" ng-app="KoobooApp" style=""><div class="freshwidget-container responsive" data-html2canvas-ignore="true" id="FreshWidget" style="display: none;"><div class="widget-ovelay" id="freshwidget-overlay"> </div><div class="freshwidget-dialog" id="freshwidget-dialog"><div class="widget-close" id="freshwidget-close"></div><div class="mobile-widget-close" id="mobile-widget-close"></div><div class="mobile-widget-arrow" id="mobile-widget-arrow"></div> <div class="frame-container"> </div><iframe allowtransparency="true" frameborder="0" id="freshwidget-frame" scrolling="auto" src="https:///en.pinnaclesportshelp.com/loading.html?ver=2" style="height: 500px" title="Feedback Form"> &lt;/div&gt;&lt;/div&gt;</iframe></div></div><div class="freshwidget-button fd-btn-left" data-html2canvas-ignore="true" id="freshwidget-button" style="display: none; top: 235px;"><a class="freshwidget-theme" href="javascript:void(0)" style="color: white; background-color: rgb(249, 101, 0); border-color: white;">Support</a></div><iframe frameborder="no" id="cookiepolicy" onload="this.style.visibility = 'visible';" scrolling="no" src="https://www.pinnacle.com/en/cookiepolicy/index?&amp;ui=desktop&amp;referDomain=https://www.pinnacle.com&amp;w=860&amp;h=600" style="visibility: visible; padding: 0px; margin: 0px; height: 72px; width: 100%;"></iframe>
# <script>
#   dataLayer = [{
#     'page-name': 'Odds~PreGame',
#     'page-category': 'Odds',
#     'domain': 'www.pinnacle.com',
#     'site': 'Guest',
#     'referrer': '0',
#     'language': 'en-GB'
#   }];
#     var refer = (function (name) {
#         var value = "; " + document.cookie;
#         var parts = value.split("; " + name + "=");
#         if (parts.length == 2) return parts.pop().split(";").shift();
#     })('refer');
#     if (!!refer) {
#         dataLayer[0]['referrer'] = refer;
#     }
# </script>
# <!-- Google Tag Manager -->
# <noscript>&lt;iframe src="//www.googletagmanager.com/ns.html?id=GTM-PSRW2G"
# height="0" width="0" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;</noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});
#   var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&amp;l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PSRW2G');</script>
# <!-- End Google Tag Manager -->
# <div class="guestlinespage" id="body-container">
# <header class="en-code" id="header">
# <script type="text/javascript">
#
#     (function () {
#
#         var k = this.kooboo = this.kooboo || {};
#
#         k.isPageContainingOdds = true;
#         k.enableRedirectionToCustomersView = true;
#
#         k.authenticationUrl = '/en/authenticate';
#         k.balanceWebApiUrl = 'https://beta.pinnacle.com/WebApi/1.26/api/v1/MembersLines/customer/balance';
#
# 		k.enableSimultaneousLogin = true;
#         k.simultaneousLoginLoaderScriptUrl = 'https://members.pinnacle.com/en/simultaneous-login/loader?logoutUrl=https://www1.pinnacle.com/members/LogOut.asp';
#
# 		k.isSelfExclusionEnabled = false;
#         k.selfExclusionApiUrl = '';
#
#         k.views = k.views || {};
#
#
#                         k.views.e = {"name":"Euro","homePageUrl":"https://beta.pinnacle.com/en/","leaguePageUrl":"https://beta.pinnacle.com/en/Sports/{sportid}/Leagues/{leagueid}"};
#
#
#                         k.views.s = {"name":"Asian","homePageUrl":"https://members.pinnacle.com/Sportsbook","leaguePageUrl":null};
#
#
#                         k.views.d = {"name":"Asian","homePageUrl":"https://members.pinnacle.com/Sportsbook","leaguePageUrl":null};
#
#
#                         k.views.g = {"name":"Asian","homePageUrl":"https://members.pinnacle.com/Sportsbook","leaguePageUrl":null};
#
#
#                         k.views.c = {"name":"Classic","homePageUrl":"https://www1.pinnacle.com/members/canvas.asp","leaguePageUrl":null};
#
#
#     }());
#
# </script>
# <script src="/Guest/Kooboo-Resource/scripts/1_0_0_20171103192757/True/member" type="text/javascript"></script>
# <div class="tophalf header-members" ps-member-only="">
# <div class="global-width">
# <span class="left-side">
# <span class="res-reponsive-menu-open">open</span>
# <a alt="Pinnacle" class="header-item logo-small" href="/en/"></a>
# <div class="header-item lang">
# <div class="language-selector dropdown-button-flat">
# <div class="container">
# <span class="text">
# <span class="flag en">
#                     English (International)
#                 </span>
# </span>
# </div>
# <ul style="display: none; opacity: 1; position: absolute;">
# <li class="active">
# <a class="value" data-value="2" href="/en/odds/match/basketball/usa/nba?sport=True">
# <span class="flag en">English (International)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="18" href="/ja/odds/match/basketball/usa/nba?sport=True">
# <span class="flag ja">日本語 (Japanese)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="3" href="/zh-cn/odds/match/basketball/usa/nba?sport=True">
# <span class="flag zh-cn">简体中文 (Chinese S.)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="19" href="/ko/odds/match/basketball/usa/nba?sport=True">
# <span class="flag ko">한국어 (Korean)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="4" href="/zh-tw/odds/match/basketball/usa/nba?sport=True">
# <span class="flag zh-tw">繁體中文 (Chinese T.)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="9" href="/no/odds/match/basketball/usa/nba?sport=True">
# <span class="flag no">Norsk (Norwegian)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="22" href="/cs/odds/match/basketball/usa/nba?sport=True">
# <span class="flag cs">Čeština (Czech)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="15" href="/pl/odds/match/basketball/usa/nba?sport=True">
# <span class="flag pl">Polski (Polish)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="5" href="/fi/odds/match/basketball/usa/nba?sport=True">
# <span class="flag fi">Suomi (Finnish)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="10" href="/pt/odds/match/basketball/usa/nba?sport=True">
# <span class="flag pt">Português (Portuguese)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="16" href="/fr/odds/match/basketball/usa/nba?sport=True">
# <span class="flag fr">Français (French)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="11" href="/ru/odds/match/basketball/usa/nba?sport=True">
# <span class="flag ru">Русский (Russian)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="6" href="/de/odds/match/basketball/usa/nba?sport=True">
# <span class="flag de">Deutsch (German)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="12" href="/es/odds/match/basketball/usa/nba?sport=True">
# <span class="flag es">Español (Spanish)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="7" href="/he/odds/match/basketball/usa/nba?sport=True">
# <span class="flag he">עברית (Hebrew)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="13" href="/sv/odds/match/basketball/usa/nba?sport=True">
# <span class="flag sv">Svenska (Swedish)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="8" href="/it/odds/match/basketball/usa/nba?sport=True">
# <span class="flag it">Italiano (Italian)</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="odds-selector-container">
# <script type="text/javascript">
#     function fnPlaceItemFirst($scope, element, apply) {
#         if (element != null){
#             var item = element.parent("li");
#             var parent = item.parent("ul");
#             if (apply) {
#                 $scope.$apply(function() {
#                     item.prependTo(parent);
#                 });
#             } else {
#                 item.prependTo(parent);
#             }
#         }
#     }
#
#     function fnInitOddsCombo($scope, $element) {
#
#         var oddSelector = $($element).find(".odds-selector");
#
#         oddSelector.dropdownButton({
#             onItemSelected: function() {
#                 $scope.oddSelected($(this).data('value'));
#                 window.pinnacle.setUserPrefsCookie("priceStyle", $(this).data('value'));
#                 fnPlaceItemFirst($scope, $(this), true);
#             }
#         });
#         var cookieValue = window.pinnacle.getUserPrefsCookie("priceStyle");
#         var currentItem = null;
#         if (!!cookieValue) {
#           	cookieValue = cookieValue.toLowerCase();
#           	currentItem = oddSelector.find('ul li a[data-value="' + cookieValue + '"]');
#         } else {
#             var items = oddSelector.find('ul li');
#             if (items.length &gt; 0) {
#                 currentItem = $(items[0]);
#             }
#         }
#         if (currentItem != null){
#             currentItem.addClass("active");
#             oddSelector.find('.text').text(currentItem.text());
#         }
#         fnPlaceItemFirst($scope, currentItem, false);
#         $element.removeClass('hide');
#     }
# </script>
# <div class="ng-scope" ng-controller="OddsController" ng-init="init('fnInitOddsCombo', true)">
# <div class="odds-selector">
# <div class="container"><span class="text">Decimal Odds</span></div>
# <ul style="display: none; opacity: 1; position: absolute;"><li>
# <a class="active" data-value="decimal">Decimal Odds</a>
# </li>
# <li>
# <a data-value="american">American Odds</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </span>
# <span class="right-side">
# <div class="deposit-button-container">
# <a class="button green-bg" height="600" href="#" id="depositButton" ps-click-modal="" url="https://www1.pinnacle.com/Members/Cashier.asp?notemplate" width="1000">Deposit</a>
# </div>
# <div class="header-item balance-menu-container">
# <div class="balance-menu dropdown loading">
# <div class="container">
# <span class="text">
# <span class="text-loading">Updating balance...</span>
# <span class="text-error">Failed to load.</span>
# <span class="text-loaded"></span>
# <a class="icon-balance-refresh" href="#"></a>
# </span>
# </div>
# <ul style="display:none">
# <li aria-controls=".balance-menu" class="balance-menu-item" data-target=".balance-menu">
# <a class="value" height="600" href="#" ps-click-modal="" url="https://www1.pinnacle.com/Members/Cashier.asp?notemplate" width="1000">Deposit / Withdraw</a>
# </li>
# <li aria-controls=".balance-menu" class="balance-menu-item" data-target=".balance-menu">
# <a class="value" height="600" href="#" ps-click-modal="" url="https://www1.pinnacle.com/members/canvas.asp?noTemplate#/members/AccountReportMenu.asp?notemplate" width="1000">Account History</a>
# </li>
# <li aria-controls=".balance-menu" class="balance-menu-item" data-target=".balance-menu">
# <a class="value" height="600" href="#" ps-click-modal="" url="https://www.pinnacle.com/en/payments?members=true" width="1000">Payment options</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="header-item account-menu-container">
# <div class="account-menu dropdown">
# <div class="container">
# <span class="text">
#                 Updating...
#             </span>
# </div>
# <ul style="display:none">
# <li aria-controls=".account-menu" class="account-menu-item" data-target=".account-menu">
# <a class="value" height="600" href="#" ps-click-modal="" url="https://www1.pinnacle.com/members/canvas.asp?noTemplate#/Members/AccountDetails.asp?notemplate" width="1000">Personal Details</a>
# </li>
# <li aria-controls=".account-menu" class="account-menu-item" data-target=".account-menu">
# <a class="value" href="https://www1.pinnacle.com/members/LogOut.asp" ps-no-cache="" target="_self">Logout</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="header-item icon-help-container">
# <a href="#" onclick="window.FreshWidget.show(); return false;" title="Help">
# <span class="icon-help"></span>
# <span class="text-help">Help</span>
# </a>
# </div>
# </span>
# </div>
# </div>
# <div class="tophalf header-guest" ps-guest-only="">
# <div class="global-width">
# <span class="res-reponsive-menu-open">open</span>
# <a class="logo" href="/en/">Pinnacle</a>
# <div class="header-item lang">
# <div class="language-selector dropdown-button-flat">
# <div class="container">
# <span class="text">
# <span class="flag en">
#                     English (International)
#                 </span>
# </span>
# </div>
# <ul style="display: none; opacity: 1; position: absolute;">
# <li class="active">
# <a class="value" data-value="2" href="/en/odds/match/basketball/usa/nba?sport=True">
# <span class="flag en">English (International)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="18" href="/ja/odds/match/basketball/usa/nba?sport=True">
# <span class="flag ja">日本語 (Japanese)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="3" href="/zh-cn/odds/match/basketball/usa/nba?sport=True">
# <span class="flag zh-cn">简体中文 (Chinese S.)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="19" href="/ko/odds/match/basketball/usa/nba?sport=True">
# <span class="flag ko">한국어 (Korean)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="4" href="/zh-tw/odds/match/basketball/usa/nba?sport=True">
# <span class="flag zh-tw">繁體中文 (Chinese T.)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="9" href="/no/odds/match/basketball/usa/nba?sport=True">
# <span class="flag no">Norsk (Norwegian)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="22" href="/cs/odds/match/basketball/usa/nba?sport=True">
# <span class="flag cs">Čeština (Czech)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="15" href="/pl/odds/match/basketball/usa/nba?sport=True">
# <span class="flag pl">Polski (Polish)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="5" href="/fi/odds/match/basketball/usa/nba?sport=True">
# <span class="flag fi">Suomi (Finnish)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="10" href="/pt/odds/match/basketball/usa/nba?sport=True">
# <span class="flag pt">Português (Portuguese)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="16" href="/fr/odds/match/basketball/usa/nba?sport=True">
# <span class="flag fr">Français (French)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="11" href="/ru/odds/match/basketball/usa/nba?sport=True">
# <span class="flag ru">Русский (Russian)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="6" href="/de/odds/match/basketball/usa/nba?sport=True">
# <span class="flag de">Deutsch (German)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="12" href="/es/odds/match/basketball/usa/nba?sport=True">
# <span class="flag es">Español (Spanish)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="7" href="/he/odds/match/basketball/usa/nba?sport=True">
# <span class="flag he">עברית (Hebrew)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="13" href="/sv/odds/match/basketball/usa/nba?sport=True">
# <span class="flag sv">Svenska (Swedish)</span>
# </a>
# </li>
# <li class="">
# <a class="value" data-value="8" href="/it/odds/match/basketball/usa/nba?sport=True">
# <span class="flag it">Italiano (Italian)</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="odds-selector-container">
# <script type="text/javascript">
#     function fnPlaceItemFirst($scope, element, apply) {
#         if (element != null){
#             var item = element.parent("li");
#             var parent = item.parent("ul");
#             if (apply) {
#                 $scope.$apply(function() {
#                     item.prependTo(parent);
#                 });
#             } else {
#                 item.prependTo(parent);
#             }
#         }
#     }
#
#     function fnInitOddsCombo($scope, $element) {
#
#         var oddSelector = $($element).find(".odds-selector");
#
#         oddSelector.dropdownButton({
#             onItemSelected: function() {
#                 $scope.oddSelected($(this).data('value'));
#                 window.pinnacle.setUserPrefsCookie("priceStyle", $(this).data('value'));
#                 fnPlaceItemFirst($scope, $(this), true);
#             }
#         });
#         var cookieValue = window.pinnacle.getUserPrefsCookie("priceStyle");
#         var currentItem = null;
#         if (!!cookieValue) {
#           	cookieValue = cookieValue.toLowerCase();
#           	currentItem = oddSelector.find('ul li a[data-value="' + cookieValue + '"]');
#         } else {
#             var items = oddSelector.find('ul li');
#             if (items.length &gt; 0) {
#                 currentItem = $(items[0]);
#             }
#         }
#         if (currentItem != null){
#             currentItem.addClass("active");
#             oddSelector.find('.text').text(currentItem.text());
#         }
#         fnPlaceItemFirst($scope, currentItem, false);
#         $element.removeClass('hide');
#     }
# </script>
# <div class="ng-scope" ng-controller="OddsController" ng-init="init('fnInitOddsCombo', true)">
# <div class="odds-selector">
# <div class="container"><span class="text">Decimal Odds</span></div>
# <ul style="display: none; opacity: 1; position: absolute;"><li>
# <a class="active" data-value="decimal">Decimal Odds</a>
# </li>
# <li>
# <a data-value="american">American Odds</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <span class="desktop-login">
# <script src="https://www.pinnacle.com/en/account-recovery/loader?ref=guestsite&amp;iframeid=forgotlogin&amp;ui=desktop"></script>
# <script type="text/javascript">
#     $(function () {
#         window.pinnacle.AssignForgotHandlers();
# 		var loginButton = $("#loginControlsButton");
# 		loginButton.on('click', submitForm);
# 		$("#loginMvc .customerId, #loginMvc .password").keyup(function (event) {
# 		    if (event.keyCode == 13) {
# 		        $(".login-container form").submit();
# 		    }
# 		});
# 	});
#
# 	function submitForm(e) {
# 		e.preventDefault();
# 		$(".login-container form").submit();
# 	}
#
# </script>
#
# ﻿<link href="/Cms_Data/Sites/Guest/Themes/Default/pinnacle/simpleModal.css" rel="stylesheet" type="text/css"/>
# <link href="/Cms_Data/Sites/Guest/Themes/Default/pinnacle/simpleModal_ie.css" rel="stylesheet" type="text/css"/>
# <div class="basic-modal-content" id="forgotPasswordContent">
# <iframe class="forgotPasswordIFrame" data-src="https://www1.pinnacle.com/ForgotPasswordV2.asp?language=British&amp;lext=bri&amp;cdn=cdn1&amp;cms=1" id="forgotPasswordIFrame"></iframe>
# </div>
# <div class="login-container">
# <ul class="quicklinks login-buttons">
# <li><a class="button blue-bg login" href="#" id="loginControlsButton">Login</a></li>
# <li><a class="button green-bg signup-link" href="/signup/desktop/en-GB?ico=menuopen" rel="nofollow" target="_blank">Open Account</a></li>
# </ul>
# <div class="login-inputs">
# <div id="loginMvc" runat="server">
# <script type="text/javascript">
#             var PSLOGIN = PSLOGIN || {};
#             PSLOGIN.showOverlay = false;
#         </script>
# <form action="/login/authenticate/Classic/en-GB" class="loginForm ng-pristine ng-valid" method="post" name="loginForm">
# <div class="loginMainContent">
# <div class="loginContainer">
# <div class="loginFormInputs">
# <div class="loginInputContainer">
# <div class="loginInputNoBorder">
# <!-- fake fields are a workaround for chrome autofill -->
# <input name="fakeusernameremembered" style="display: none;" type="text"/>
# <input name="fakepasswordremembered" style="display: none;" type="password"/>
# </div>
# </div>
# <div class="loginInputContainer">
# <div class="loginLabel">
# <label>Client ID:</label>
# </div>
# <div class="loginInput">
# <input autofocus="" class="customerId" maxlength="10" name="CustomerId" placeholder="Client Id" tabindex="1" type="text"/>
# </div>
# </div>
# <div class="loginInputContainer">
# <div class="loginLabel">
# <label>Password:</label>
# </div>
# <div class="loginInput">
# <input autocomplete="off" class="password" maxlength="10" name="Password" placeholder="Password" tabindex="2" type="password" value=""/>
# </div>
# </div>
# </div>
# <div id="loginButtonContainer">
# <input class="loginSubmit" data-theme="d" name="loginSubmit" tabindex="3" type="submit" value="Login"/>
# <div class="loginLoading hidden" id="loginLoadingImg">
# <img src="/login//WebShared//shared/Images/loading.gif"/>
#                 Authenticating...
#             </div>
# </div>
# </div>
# <div class="lostLogin">
# </div>
# </div>
# <input name="AppId" type="hidden" value="Classic"/>
# <input id="PostAction" type="hidden" value="/login/authenticate/Classic/en-GB"/></form>
# <script src="/Login/Scripts/js?v=T-7dTp5WUmKU3mR57bntXhXj-oSvEKwaIqvLH3Rw80c1"></script>
# </div>
# </div>
# <div class="login-links">
# <a href="#recover-client-id-by-email">Forgot Client ID?</a>
# <a href="#" id="forgotPassword">Forgot password?</a>
# </div>
# </div>
# </span>
# <span class="mobile-login">
# <div id="loginPopup" style="display: none">
# <div class="login__wrapper">
# <div class="login__wrapper__holder">
# <a class="login__dynamicbox" href="/signup/desktop/en-GB">
# <div class="login__dynamicbox__image" style="background-image: url('/Cms_Data/Contents/Guest/Media/Login-pages/not-a-member-login.jpg');" title="Not a member? Open an account">
# </div>
# <div class="login__dynamicbox__caption">
#                             Not a member? <div style="text-decoration: underline;">Open an account</div>
# </div>
# </a>
# <div class="login__form">
# <h1 class="login__form__title">Login</h1>
# <div id="loginMvc" runat="server"> <script type="text/javascript">
#             var PSLOGIN = PSLOGIN || {};
#             PSLOGIN.showOverlay = false;
#         </script>
# <form action="/login/authenticate/Classic/en-GB" class="loginForm" method="post" name="loginForm">
# <div class="loginMainContent">
# <div class="loginContainer">
# <div class="loginFormInputs">
# <div class="loginInputContainer">
# <div class="loginInputNoBorder">
# <!-- fake fields are a workaround for chrome autofill -->
# <input name="fakeusernameremembered" style="display: none;" type="text"/>
# <input name="fakepasswordremembered" style="display: none;" type="password"/>
# </div>
# </div>
# <div class="loginInputContainer">
# <div class="loginLabel">
# <label>Client ID:</label>
# </div>
# <div class="loginInput">
# <input autofocus="" class="customerId" maxlength="10" name="CustomerId" tabindex="1" type="text"/>
# </div>
# </div>
# <div class="loginInputContainer">
# <div class="loginLabel">
# <label>Password:</label>
# </div>
# <div class="loginInput">
# <input autocomplete="off" class="password" maxlength="10" name="Password" tabindex="2" type="password" value=""/>
# </div>
# </div>
# </div>
# <div id="loginButtonContainer">
# <input class="loginSubmit" data-theme="d" name="loginSubmit" tabindex="3" type="submit" value="Login"/>
# <div class="loginLoading hidden" id="loginLoadingImg">
# <img src="/login//WebShared//shared/Images/loading.gif"/>
#                 Authenticating...
#             </div>
# </div>
# </div>
# <div class="lostLogin">
# </div>
# </div>
# <input name="AppId" type="hidden" value="Classic"/>
# <input id="PostAction" type="hidden" value="/login/authenticate/Classic/en-GB"/></form>
# <script src="/Login/Scripts/js?v=T-7dTp5WUmKU3mR57bntXhXj-oSvEKwaIqvLH3Rw80c1"></script>
# </div>
# <div class="fields">
#  ﻿<link href="/Cms_Data/Sites/Guest/Themes/Default/pinnacle/simpleModal.css" rel="stylesheet" type="text/css"/>
# <link href="/Cms_Data/Sites/Guest/Themes/Default/pinnacle/simpleModal_ie.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#    $(function () {
#        window.pinnacle.AssignForgotHandlers();
#    });
# </script>
# <p class="text">Forgot <a href="#recover-client-id-by-email">Client ID</a>, <a href="#recover-email-by-client-id">email</a> or <a href="#" id="forgotPassword">password</a>?</p>
# <div class="basic-modal-content" id="forgotPasswordContent">
# <iframe class="forgotPasswordIFrame" data-src="https://www1.pinnacle.com/ForgotPasswordV2.asp?language=British&amp;lext=bri&amp;cdn=CDN1&amp;cms=1" id="forgotPasswordIFrame"></iframe>
# </div>
# <script src="https://www.pinnacle.com/en/account-recovery/loader?ref=guestsite&amp;iframeid=forgotlogin&amp;ui=desktop"></script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     $(function () {
#         var loginButton = $("#loginButton");
#         if (location.protocol === 'https:') {
#             loginButton.on('click',showLoginPopup);
# 			setTimeout(loadLoginContent);
#         } else {
#             loginButton.attr("href", "https://www.pinnacle.com/en/login");
#         }
#     });
#     function loadLoginContent() {
#         var loginPopup = $("#loginPopup");
#         $.get("/en/login-popup", function(data) {
#             try {
#                 loginPopup.html(data);
#             }
#             finally {
#
# 				window.pinnacle.AssignForgotHandlers();
#             }
#         });
#     }
#     function showLoginPopup(e) {
#         e.preventDefault();
#         var loginPopup = $("#loginPopup");
#         if (!loginPopup.data('loaded')) {
#             loginPopup.data('loaded', true);
#             loadLoginContent(loginPopup);
#             loginPopup.dialog({
#                 dialogClass: "login-close",
#                 draggable: false,
#                 modal: true,
#                 resizable: false,
#                 width: 750,
#                 height: 500,
#                 open: function() {
#                     $('.ui-widget-overlay').addClass('login-overlay');
#                 },
#                 close: function() {
#                     $('.ui-widget-overlay').removeClass('login-overlay');
#                 }
#             });
#         } else {
#             loginPopup.dialog('open');
#         }
#         loginPopup.click(function (e) {
#         	var wrapper = loginPopup.find(".login__wrapper");
#         	var holder = loginPopup.find(".login__wrapper__holder");
#             if (e.target == loginPopup[0] || e.target == wrapper[0] || e.target == holder[0]) {
#                 loginPopup.dialog('close');
#             }
#         });
#         $(".login-overlay").click(function () { loginPopup.dialog('close'); });
#     }
# </script>
# <ul class="quicklinks">
# <li>
# <a class="button blue-bg login" href="#" id="loginButton">Login</a>
# </li>
# <li>
# <a class="button green-bg signup-link desktop" href="/signup/desktop/en-GB?ico=menuopen" rel="nofollow" target="_blank">Open Account</a>
# <a class="button green-bg signup-link mobile" href="/m/Mobile/SignUp#signupContainer" rel="nofollow" target="_blank">Open Account</a>
# </li>
# </ul>
# </span>
# </div>
# </div>
# <nav class="nav upper-nav">
# <div class="global-width">
# <ul class="tabs">
# <li class="active">
# <a class="button tab" href="/en/">Sports Betting</a>
# </li>
# <li><a class="button tab" href="/en/casino/">Casino</a></li>
# <li><a class="button tab" href="/en/casino/live-casino">Live Casino</a></li>
# <li id="esportsTab"><a class="button tab" href="/en/esports">eSports</a></li>
# <li>
# <a class="button tab" href="/en/betting-resources">Betting Resources</a>
# </li>
# <li><a class="button tab" href="/en/mobile">Mobile</a></li>
# </ul>
# </div>
# </nav>
# <div class="nav">
# <div class="global-width">
# <ul class="list">
# </ul>
# <ul class="main">
# <li class=" home"><a href="/en/" target="">Home</a></li>
# <li class=" "><a href="/en/promotions" target="">Why Pinnacle?</a></li>
# <li class=" "><a href="/en/payment-options" target="">Payment Options</a></li>
# </ul>
# </div>
# </div>
# </header>
# <div id="main-container">
# <div class="body-background">
# <div class="full-background" style="background: url(/Cms_Data/Contents/Guest/Media/homepage/bg-takeover/Generic/en-generic-hp-background.jpg) no-repeat center top;" title=""></div>
# </div>
# <div class="global-width">
# <div class="container guestlines-table">
# <div class="guestlines-row">
# <aside class="left guestlines-cell-left" id="sidebar">
# <div class="block sports-menu default active">
# <h6 class="title">Betting Menu</h6>
# <ul>
# <li class="level-1 live ">
# <span class="text"><span title="Live In-play"></span>Live In-play</span>
# <ul style="">
# <li class="level-2 collapse">
# <span class="text"><span class="sport-icon soccer" title="Soccer"></span>Soccer</span>
# <ul style="display:none">
# <li class="collapse">
# <span class="text"><span class="trigger" title="AFC"></span>AFC</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/afc/afc-asian-cup-qualifiers-m">
#             AFC - Asian Cup Qualifiers
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Algeria"></span>Algeria</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/algeria/algeria-professional-ligue-1">
#             Professional Ligue 1
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Argentina"></span>Argentina</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/argentina/argentina-primera-b-nacional-corners">
#             Argentina - Primera B Nacional Corners
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/argentina/argentina-primera-division">
#             Primera Division
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Australia"></span>Australia</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/australia/australia-a-league-corners">
#             A League Corners
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Austria"></span>Austria</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/austria/austria-regionalliga-mitte">
#             Austria - Regionalliga Mitte
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/austria/austria-regionalliga-ost">
#             Austria - Regionalliga Ost
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/austria/austria-regionalliga-west">
#             Austria - Regionalliga West
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Belgium"></span>Belgium</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/belgium/belgium-women">
#             Belgium - Women
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/belgium/belgium-youth-league">
#             Youth League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Brazil"></span>Brazil</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/brazil/brazil-serie-a-corners">
#             Brazil - Serie A Corners
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/brazil/brazil-serie-b-corners">
#             Serie B - Corners
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Chile"></span>Chile</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/chile/chile-primera-division">
#             Primera Division
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Colombia"></span>Colombia</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/colombia/colombia-primera-a-corners">
#             Colombia - Primera A Corners
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Croatia"></span>Croatia</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/croatia/croatian-cup">
#             Croatian Cup
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Czech Republic"></span>Czech Republic</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/czech-republic/czech-republic-2-liga">
#             2. Liga
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/czech-republic/czech-republic---u19-league">
#             Czech Republic - U19 League
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/czech-republic/czech-republic-u21-league">
#             U21 League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Denmark"></span>Denmark</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/denmark/denmark-elitedivisionen-women">
#             Denmark - Elitedivisionen Women
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/denmark/denmark-reserve-league">
#             Reserve League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Ecuador"></span>Ecuador</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/ecuador/ecuador-primera-b">
#             Ecuador - Primera B
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/ecuador/ecuador-serie-a-corners">
#             Ecuador - Serie A Corners
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/ecuador/ecuador-serie-a">
#             Serie A
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Egypt"></span>Egypt</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/egypt/egypt-cup">
#             Egypt - Cup
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="England"></span>England</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/england/england-professional-development-league">
#             England - Professional Development League
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/england/england-isthmian-premier-league">
#             Isthmian Premier League
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/england/england-league-1">
#             League 1
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/england/england-northern-premier-league">
#             Northern Premier League
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/england/england-southern-premier-league">
#             Southern Premier League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="France"></span>France</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/france/france-u19-league">
#             France - U19 League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Friendlies - International"></span>Friendlies - International</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/friendlies---international/friendlies-international">
#             International Friendlies
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/friendlies---international/international-friendlies-women">
#             International Friendlies - Women
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/friendlies---international/international-friendlies-corners">
#             International Friendlies Corners
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/friendlies---international/international-friendlies-u20">
#             International Friendlies U20
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Germany"></span>Germany</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-oberliga-bayern-nord">
#             Germany - Oberliga Bayern Nord
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-oberliga-bayern-sud">
#             Germany - Oberliga Bayern Sud
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-oberliga-hamburg">
#             Germany - Oberliga Hamburg
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-oberliga-hessen">
#             Germany - Oberliga Hessen
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-oberliga-westfalen">
#             Germany - Oberliga Westfalen
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-regionalliga-north-corners">
#             Germany - Regionalliga North Corners
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-regionalliga-south-west-corners">
#             Germany - Regionalliga South West Corners
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-regionalliga-west-corners">
#             Germany - Regionalliga West Corners
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-regionalliga-bavaria">
#             Regionalliga Bavaria
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-regionalliga-bavaria-corners">
#             Regionalliga Bavaria Corners
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-regionalliga-north">
#             Regionalliga North
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-regionalliga-south-west">
#             Regionalliga South West
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/germany/germany-regionalliga-west">
#             Regionalliga West
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Gibraltar"></span>Gibraltar</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/gibraltar/gibraltar---premier-division">
#             Gibraltar - Premier Division
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Greece"></span>Greece</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/live/soccer/greece/greece---football-league">
#             Greece - Football League
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/live/soccer/greece/greece-superleague">
#             Superleague
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="India"></span>India</span>
# <ul style="display: none;">
# <li class="">
# ...
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/basketball/italy/italy-lega-nazionale-pallacanestro-gold">
#             Lega Nazionale Pallacanestro Gold
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Japan"></span>Japan</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/japan/japan-b-league">
#             Japan - B League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Norway"></span>Norway</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/norway/norway-blno">
#             BLNO
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Poland"></span>Poland</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/poland/poland-tauron-basket-liga">
#             Tauron Basket Liga
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Romania"></span>Romania</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/romania/romania-division-a">
#             Division A
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Slovenia"></span>Slovenia</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/slovenia/slovenia-1-a-skl">
#             1.A SKL
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="South Korea"></span>South Korea</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/south-korea/korea-basketball-league">
#             Korea Basketball League
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/basketball/south-korea/korea-wkbl">
#             WKBL
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Spain"></span>Spain</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/spain/spain-acb">
#             ACB
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/basketball/spain/spain-leb-gold">
#             LEB Gold
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Switzerland"></span>Switzerland</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/switzerland/switzerland-lna">
#             LNA
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Turkey"></span>Turkey</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/turkey/turkey-super-league-2">
#             Turkey - Super League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="USA"></span>USA</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/basketball/usa/nba">
#             NBA
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/basketball/usa/ncaa">
#             NCAA
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="level-2 collapse">
# <span class="text"><span class="sport-icon biathlon" title="Biathlon"></span>Biathlon</span>
# <ul style="display:none">
# <li class="collapse">
# <span class="text"><span class="trigger" title="World"></span>World</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/biathlon/world/world-cup-overall-matchups-men">
#             World Cup Overall Matchups - Men
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="level-2 collapse">
# <span class="text"><span class="sport-icon boxing" title="Boxing"></span>Boxing</span>
# <ul style="display:none">
# <li><a class="text " href="/en/odds/today/boxing">
#         Today
#         <div class="marker"></div>
# </a>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="International"></span>International</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/boxing/international/boxing-matches">
#             Boxing Matches
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="level-2 collapse">
# <span class="text"><span class="sport-icon darts" title="Darts"></span>Darts</span>
# <ul style="display:none">
# <li><a class="text " href="/en/odds/today/darts">
#         Today
#         <div class="marker"></div>
# </a>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="International"></span>International</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/darts/international/grand-slam-of-darts">
#             Grand Slam of Darts
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="level-2 collapse">
# <span class="text"><span class="sport-icon e-sports" title="eSports"></span>eSports</span>
# <ul style="display:none">
# <li><a class="text " href="/en/odds/today/e-sports">
#         Today
#         <div class="marker"></div>
# </a>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="CS:GO"></span>CS:GO</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/c-s-go/cs-go-esl-pro-league-eu">
#             CS:GO - ESL Pro League EU
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/c-s-go/cs-go-esl-pro-league-na">
#             CS:GO - ESL Pro League NA
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/c-s-go/cs-go-esports-championship-series-eu-z">
#             CS:GO - Esports Championship Series EU
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/c-s-go/cs-go-fcdb-cup-qualifier">
#             CS:GO - FCDB Cup Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/c-s-go/cs-go-ibuypower-masters">
#             CS:GO - iBUYPOWER Masters
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/c-s-go/cs-go-vreecase-cup">
#             CS:GO - Vreecase Cup
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/c-s-go/counter-strike-global-offensive-gfinity-league">
#             Gfinity League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Dota 2"></span>Dota 2</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-dotacinema-captains-draft-eu-qualifier">
#             Dota 2 - DotaCinema Captains Draft  EU Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-dpl-top-league">
#             Dota 2 - DPL Top League
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-dreamleague-north-america-qualifier">
#             Dota 2 - DreamLeague North America Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-mdl-macau-cis-qualifier">
#             Dota 2 - MDL Macau CIS Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-mdl-macau-europe-qualifier">
#             Dota 2 - MDL Macau Europe Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-mdl-macau-south-america-qualifier">
#             Dota 2 - MDL Macau South America Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-the-summit-europe-qualifier">
#             Dota 2 - The Summit Europe Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-the-summit-south-america-qualifier">
#             Dota 2 - The Summit South America Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/dota-2/dota-2-the-summit-southeast-asia-qualifier">
#             Dota 2 - The Summit Southeast Asia Qualifier
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="King of Glory"></span>King of Glory</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/king-of-glory/king-of-glory-king-pro-league">
#             King of Glory - King Pro League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Rocket League"></span>Rocket League</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/rocket-league/rocket-league-championship-series">
#             Rocket League - Championship Series
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="StarCraft 2"></span>StarCraft 2</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/starcraft-2/starcraft-2-homestorycup">
#             HomeStoryCup
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Starcraft Broodwar"></span>Starcraft Broodwar</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/starcraft-broodwar/starcraft-broodwar-afreeca-starleague">
#             Starcraft BroodWar - Afreeca Starleague
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="World of Tanks"></span>World of Tanks</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/world-of-tanks/world-of-tanks-wargaming-league">
#             World of Tanks - Wargaming League
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="New Markets"></span>New Markets</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/e-sports/new-markets/cs-go-czech-championship">
#             CS:GO - Czech Championship
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="level-2 collapse">
# <span class="text"><span class="sport-icon football" title="Football"></span>Football</span>
# <ul style="display:none">
# <li><a class="text " href="/en/odds/today/football">
#         Today
#         <div class="marker"></div>
# </a>
# </li>
# <li class="featured">
# <a class="text " href="/en/odds/match/football/usa/nfl?sport=True">
#             NFL
#             <div class="marker"></div>
# </a>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Canada"></span>Canada</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/football/canada/canadian-football">
#             Canadian Football
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="USA"></span>USA</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/football/usa/ncaa-c">
#             NCAA
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/football/usa/nfl">
#             NFL
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="level-2 collapse">
# <span class="text"><span class="sport-icon handball" title="Handball"></span>Handball</span>
# <ul style="display:none">
# <li><a class="text " href="/en/odds/today/handball">
#         Today
#         <div class="marker"></div>
# </a>
# </li>
# <li class="featured">
# <a class="text " href="/en/odds/match/handball/france/france-division-1-men?sport=True">
#             France - Division 1 Men
#             <div class="marker"></div>
# </a>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Denmark"></span>Denmark</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/handball/denmark/handball-denmark-haandboldligaen-men">
#             Haandboldligaen Men
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Europe"></span>Europe</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/handball/europe/european-champions-league-men">
#             Champions League Men
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/handball/europe/european-champions-league-women">
#             Champions League Women
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="France"></span>France</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/handball/france/france-division-1-men">
#             France - Division 1 Men
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Germany"></span>Germany</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/handball/germany/germany-bundesliga-men-q">
#             Bundesliga Men
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Spain"></span>Spain</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/handball/spain/spain-liga-asobal-men">
#             Liga Asobal Men
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# <li class="collapse">
# <span class="text"><span class="trigger" title="Sweden"></span>Sweden</span>
# <ul style="display: none;">
# <li class="">
# <a class="text " href="/en/odds/match/handball/sweden/handball-sweden-elitserien-men">
#             Elitserien Men
#             <div class="marker"></div>
# </a>
# </li>
# <li class="">
# <a class="text " href="/en/odds/match/handball/sweden/sweden-elitserien-women">
#             Elitserien Women
#             <div class="marker"></div>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="level-2 collapse">
# <span class="text"><span class="sport-icon hockey" title="Hockey"></span>Hockey</span>
# <ul style="display:none">
# <li><a class="text " href="/en/odds/today/hockey">
#         Today
#         <div class="marker"></div>
# </a>
# </li>
# <li class="featured">
# <a class="text " href="/en/odds/match/hockey/usa/nhl-ot-included?sport=True">
#             NHL - OT Included
#             <div class="marker"></div>
# </a>
# </li>
# <li class="featured">
# <a class="text " href="/en/odds/match/hockey/usa/nhl-ot-included-alternates?sport=True">
#             NHL - OT Included Alternates
#             <div class="marker"></div>
# </a>
# </li>
# <li class="featured">
# <a class="text " href="/en/odds/match/hockey/usa/nhl-regular-time?sport=True"></a></li></ul></li></ul></li></ul></div></aside></div></div></div></div></div></body></html>
